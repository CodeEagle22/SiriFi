# %%
# !pip install /Users/deftwolf/Downloads/sirifi/dist/sirifi-0.1.5.1.tar.gz
# Out:
# Processing ./dist/sirifi-0.1.5.1.tar.gz
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.4 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from sirifi==0.1.5.1) (2.3.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from sirifi==0.1.5.1) (2.32.4)
# Requirement already satisfied: yfinance>=0.2.36 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from sirifi==0.1.5.1) (0.2.64)
# Requirement already satisfied: python-binance in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from sirifi==0.1.5.1) (1.0.29)
# Requirement already satisfied: newsapi-python in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from sirifi==0.1.5.1) (0.2.7)
# Requirement already satisfied: alpha_vantage in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from sirifi==0.1.5.1) (3.0.0)
# Requirement already satisfied: vaderSentiment in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from sirifi==0.1.5.1) (3.3.2)
# Requirement already satisfied: plotly in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from sirifi==0.1.5.1) (6.3.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from pandas>=1.4->sirifi==0.1.5.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from pandas>=1.4->sirifi==0.1.5.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from pandas>=1.4->sirifi==0.1.5.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from pandas>=1.4->sirifi==0.1.5.1) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->sirifi==0.1.5.1) (1.17.0)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from yfinance>=0.2.36->sirifi==0.1.5.1) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from yfinance>=0.2.36->sirifi==0.1.5.1) (4.3.8)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from yfinance>=0.2.36->sirifi==0.1.5.1) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from yfinance>=0.2.36->sirifi==0.1.5.1) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from yfinance>=0.2.36->sirifi==0.1.5.1) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from yfinance>=0.2.36->sirifi==0.1.5.1) (0.11.4)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from yfinance>=0.2.36->sirifi==0.1.5.1) (6.31.1)
# Requirement already satisfied: websockets>=13.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from yfinance>=0.2.36->sirifi==0.1.5.1) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.36->sirifi==0.1.5.1) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.36->sirifi==0.1.5.1) (4.14.0)
# Requirement already satisfied: cffi>=1.12.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance>=0.2.36->sirifi==0.1.5.1) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance>=0.2.36->sirifi==0.1.5.1) (2025.6.15)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.36->sirifi==0.1.5.1) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from requests->sirifi==0.1.5.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from requests->sirifi==0.1.5.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from requests->sirifi==0.1.5.1) (2.4.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from alpha_vantage->sirifi==0.1.5.1) (3.12.13)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from aiohttp->alpha_vantage->sirifi==0.1.5.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from aiohttp->alpha_vantage->sirifi==0.1.5.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from aiohttp->alpha_vantage->sirifi==0.1.5.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from aiohttp->alpha_vantage->sirifi==0.1.5.1) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from aiohttp->alpha_vantage->sirifi==0.1.5.1) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from aiohttp->alpha_vantage->sirifi==0.1.5.1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from aiohttp->alpha_vantage->sirifi==0.1.5.1) (1.20.1)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from plotly->sirifi==0.1.5.1) (2.5.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from plotly->sirifi==0.1.5.1) (25.0)
# Requirement already satisfied: dateparser in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from python-binance->sirifi==0.1.5.1) (1.2.2)
# Requirement already satisfied: pycryptodome in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from python-binance->sirifi==0.1.5.1) (3.23.0)
# Requirement already satisfied: regex>=2024.9.11 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from dateparser->python-binance->sirifi==0.1.5.1) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /opt/anaconda3/envs/sirifi/lib/python3.11/site-packages (from dateparser->python-binance->sirifi==0.1.5.1) (5.3.1)
# Building wheels for collected packages: sirifi
#   DEPRECATION: Building 'sirifi' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'sirifi'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for sirifi (setup.py) ... done
#   Created wheel for sirifi: filename=sirifi-0.1.5.1-py3-none-any.whl size=30667 sha256=cb9c16db90f46c80d94a022c508ac755cd2ba9863e5c84fc726e361cfd80fbd1
#   Stored in directory: /Users/deftwolf/Library/Caches/pip/wheels/c5/64/21/311e0c3afeaa872985ca7cc2cb736c1f39b1f5c9d75b13ef53
# Successfully built sirifi
# Installing collected packages: sirifi
#   Attempting uninstall: sirifi
#     Found existing installation: sirifi 0.1.5.1
#     Uninstalling sirifi-0.1.5.1:
#       Successfully uninstalled sirifi-0.1.5.1
# Successfully installed sirifi-0.1.5.1

# %%
from sirifi import Sirifi_C_DataStreamer, Sirifi_C_FeatureEngineering, Sirifi_C_Dashboard, Sirifi_C_ValueInvest, Sirifi_C_SentimentAnalyzer, Sirifi_C_Backtester, Sirifi_C_TradingBot

# %%
# ✅ Initialize the data fetcher with your Binance API credentials
# First, ensure you have securely loaded your API Key and Secret (e.g., from environment variables or .env file).
BINANCE_API_KEY = "QoHrpRcui2X7py9whGmGmTZyi1ZR7OQrNYmUOC2A7kHt5yx0vQ1sL2o8x8Pjztd8"
BINANCE_API_SECRET = "fniX66D2I37jS4BwCmV4m6uod6zQLMkP3pPgMtDKHFV76Wihmu85UfhSU843IbyC"

fetcher = Sirifi_C_DataStreamer(
    binance_api_key=BINANCE_API_KEY,       # Replace with your actual Binance API Key
    binance_api_secret=BINANCE_API_SECRET  # Replace with your actual Binance API Secret
)

# ✅ Define the list of base assets (cryptocurrencies) you want to fetch data for
# In this example, we are fetching data for Bitcoin (BTC), Ethereum (ETH), Cardano (ADA), Ripple (XRP), and Dogecoin (DOGE).
base_assets = ['BTC', 'ETH', 'ADA', 'XRP', 'DOGE']  

# ✅ Fetch historical OHLCV (Open, High, Low, Close, Volume) data from Binance
results = fetcher.fetch(
    base_assets=base_assets,       # List of coins for which you want to fetch data
    currency='USD',               # Quote currency: USD stablecoins like USD, USDT, USDC, BUSD, EUR, GBP (can be changed as needed)
    interval='1d',                 # Timeframe for the data: '1m', '5m', '1h', '1d', '1w', etc. ('1d' means daily data)
    source='yfinance',              # Data source: 'yfinance' & 'binance' means we are pulling data directly from Binance
    start_date='2024-09-01',       # Start date for the data range (format: 'YYYY-MM-DD')
    end_date='2025-09-23'          # End date for the data range (format: 'YYYY-MM-DD')
)

# ✅ Example: Access and print the first few rows of data for BTC and ETH

results['BTC'].head()
results['ETH'].head()
# Out:
# [Fetching] BTCUSD ...
# [Success] BTCUSD data loaded from yfinance
# [Fetching] ETHUSD ...
# /Users/deftwolf/Downloads/sirifi/sirifi/crypto_streamer.py:98: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date, interval=interval, progress=False)
# /Users/deftwolf/Downloads/sirifi/sirifi/crypto_streamer.py:98: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date, interval=interval, progress=False)
# [Success] ETHUSD data loaded from yfinance
# [Fetching] ADAUSD ...
# [Success] ADAUSD data loaded from yfinance
# [Fetching] XRPUSD ...
# /Users/deftwolf/Downloads/sirifi/sirifi/crypto_streamer.py:98: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date, interval=interval, progress=False)
# /Users/deftwolf/Downloads/sirifi/sirifi/crypto_streamer.py:98: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date, interval=interval, progress=False)
# [Success] XRPUSD data loaded from yfinance
# [Fetching] DOGEUSD ...
# [Success] DOGEUSD data loaded from yfinance
# /Users/deftwolf/Downloads/sirifi/sirifi/crypto_streamer.py:98: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date, interval=interval, progress=False)
#         Date         Open         High          Low        Close        Volume
# 0 2024-09-01  2513.424316  2515.467285  2401.889160  2427.902344  1.180044e+10
# 1 2024-09-02  2427.973389  2563.085938  2426.095947  2538.187256  1.252044e+10
# 2 2024-09-03  2538.160645  2552.802734  2419.875244  2420.603760  1.140680e+10
# 3 2024-09-04  2420.192383  2488.916504  2313.265137  2448.977051  1.670960e+10
# 4 2024-09-05  2448.986816  2465.385254  2348.863281  2367.737549  1.363233e+10

# %%
# Add up indicators and features
for asset in base_assets:
    sfe = Sirifi_C_FeatureEngineering(results[asset])
    results[asset] = sfe.get_transformed_data()

results['ETH'].head()
# Out:
#         Date         Open         High          Low        Close  \
# 0 2024-09-01  2513.424316  2515.467285  2401.889160  2427.902344
# 1 2024-09-02  2427.973389  2563.085938  2426.095947  2538.187256
# 2 2024-09-03  2538.160645  2552.802734  2419.875244  2420.603760
# 3 2024-09-04  2420.192383  2488.916504  2313.265137  2448.977051
# 4 2024-09-05  2448.986816  2465.385254  2348.863281  2367.737549
#
#          Volume  pct_return  ma_20  ma_50  ma_200  ...  bollinger_lower  \
# 0  1.180044e+10         NaN    NaN    NaN     NaN  ...              NaN
# 1  1.252044e+10    0.045424    NaN    NaN     NaN  ...              NaN
# 2  1.140680e+10   -0.046326    NaN    NaN     NaN  ...              NaN
# 3  1.670960e+10    0.011722    NaN    NaN     NaN  ...              NaN
# 4  1.363233e+10   -0.033173    NaN    NaN     NaN  ...              NaN
#
#             obv  roc  atr  candle_range  price_gap  return_std  \
# 0  0.000000e+00  NaN  NaN    113.578125        NaN         NaN
# 1  1.252044e+10  NaN  NaN    136.989990   0.071045         NaN
# 2  1.113644e+09  NaN  NaN    132.927490  -0.026611         NaN
# 3  1.782324e+10  NaN  NaN    175.651367  -0.411377         NaN
# 4  4.190920e+09  NaN  NaN    116.521973   0.009766         NaN
#
#    signal_crossover  rsi_signal  macd_cross
# 0             False     neutral        none
# 1              True     neutral        none
# 2             False     neutral        none
# 3             False     neutral        none
# 4             False     neutral     bearish
#
# [5 rows x 28 columns]

# %%
# Comparative Interactive Dashboard
dashboard = Sirifi_C_Dashboard(results, normalize=False) # Keep normalisation True for better comparison
dashboard.show()

# %%
# =======================
# Initialize Sentiment Analyzer
# =======================
cs = Sirifi_C_SentimentAnalyzer(
    # Binance API keys for market data access
    # Binance API credentials: used to access Binance account data and market information
    binance_key=BINANCE_API_KEY,
    binance_secret=BINANCE_API_SECRET,
    
    # Reddit credentials to pull social sentiment data
    # Reddit API credentials: used to fetch posts/comments for sentiment analysis
    reddit_id=REDDIT_CLIENT_ID,
    reddit_secret=REDDIT_CLIENT_SECRET,
    reddit_agent=REDDIT_USER_AGENT,
    
    # List of cryptocurrency symbols to analyze (base coins only, no quote currency)
    symbols=['ADA', 'XRP', 'BNB'],  
    
    # Optional: You can set a quote asset, e.g., "USDC", default is "USDT"
    # quote_asset="USDC",
    
    # Filter coins by market cap (or trading volume) to focus on significant coins
    min_marketcap=10_000_000_000,  # 10B USD
    
    # Candlestick interval: "1d" means daily candles
    interval="1d",  
    
    # Limit the number of candles to fetch; 1 here will fetch the most recent candle
    limit=1  
)

# =======================
# Run analysis
# =======================
df = cs.run()  # Executes the sentiment analysis and returns a DataFrame with results

# Display the resulting DataFrame
df
# Out:
#   Symbol  currentPrice  priceChange priceSentiment  redditScore  \
# 0    ADA        0.8894    -0.470009        Neutral        0.456
# 1    BNB     1051.7900     0.701798        Neutral        0.323
# 2    XRP        2.9870     0.339279        Neutral       -0.023
#
#   redditSentiment     marketCap  tradingVolume
# 0        Positive  3.126344e+10   2.945151e+07
# 1        Positive  1.514634e+11   1.708146e+08
# 2         Neutral  1.714729e+11   1.999546e+08
